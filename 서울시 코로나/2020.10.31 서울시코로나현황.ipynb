# %% [markdown]
# # 서울시에서 공개한 코로나19 발생동향 분석
#
# * http://www.seoul.go.kr/coronaV/coronaStatus.do

# %%
import pandas as pd
import numpy as np

# %%
url= "http://www.seoul.go.kr/coronaV/coronaStatus.do"
url
# Out:
# 'http://www.seoul.go.kr/coronaV/coronaStatus.do'

# %%
table = pd.read_html(url)

# %%
table[0]
# Out:
#    종로구   중구  용산구  성동구  광진구  동대문구  중랑구  성북구  강북구  도봉구  노원구  은평구 서대문구
# 0   95   66  143  138  140   178  210  350  159  228  333  266  137
# 1    0   +1    0   +2   +1    +3   +1   +3    0    0   +1   +2    0
# 2  마포구  양천구  강서구  구로구  금천구  영등포구  동작구  관악구  서초구  강남구  송파구  강동구   기타
# 3  187  194  305  203   98   210  262  473  230  341  392  204  469
# 4   +1   +3   +2   +2    0    +2    0   +4   +2   +9   +6   +1   +6

# %%
table[1]
# Out:
#      종로구   중구  용산구  성동구  광진구 동대문구
# 0     95   66  143  138  140  178
# 1      0   +1    0   +2   +1   +3
# 2    중랑구  성북구  강북구  도봉구  노원구  은평구
# 3    210  350  159  228  333  266
# 4     +1   +3    0    0   +1   +2
# 5   서대문구  마포구  양천구  강서구  구로구  금천구
# 6    137  187  194  305  203   98
# 7      0   +1   +3   +2   +2    0
# 8   영등포구  동작구  관악구  서초구  강남구  송파구
# 9    210  262  473  230  341  392
# 10    +2    0   +4   +2   +9   +6
# 11   강동구   기타  NaN  NaN  NaN  NaN
# 12   204  469  NaN  NaN  NaN  NaN
# 13    +1   +6  NaN  NaN  NaN  NaN

# %%
table[2]
# Out:
#      소계  해외유입  동대문구 요양시설 관련  송파구 소재 병원 관련  강남구 헬스장 관련  강남구 럭키 사우나 관련  \
# 0  6011   455            10             8          13             31
#
#    제주도 골프 모임 관련  강남구 역삼역 관련  종로구 고등학교 관련  은평구 방문교사 관련  ...  강남구 CJ텔레닉스 관련  \
# 0             4           3            3            7  ...             20
#
#    용인시 동문골프 모임 관련  강남서초 지인 모임  송파구 소재 교회 관련  수도권 골프 모임 관련  생일파티 모임 관련  \
# 0              25          27             6             5           6
#
#    도봉구 다나 병원  타 시·도 확진자 접촉자    기타  감염경로 조사중
# 0         68            261  4027      1022
#
# [1 rows x 21 columns]

# %%
table[3]
# Out:
#         연번     환자     확진일  거주지     여행력         접촉력 퇴원현황
# 0     6011  26507  10.30.  구로구       -  강남구 헬스장 관련  NaN
# 1     6010  26503  10.30.  타시도       -  강남구 헬스장 관련  NaN
# 2     6009  26495  10.30.  구로구       -  강남구 헬스장 관련  NaN
# 3     6008  26492  10.30.  관악구       -   기타 확진자 접촉  NaN
# 4     6007  26468  10.30.  타시도       -    감염경로 조사중  NaN
# ...    ...    ...     ...  ...     ...         ...  ...
# 6006     5      9   1.31.  성북구       -       #5 접촉   퇴원
# 6007     4      7   1.30.  마포구  중국 우한시       해외 접촉   퇴원
# 6008     3      6   1.30.  종로구       -       #3 접촉   퇴원
# 6009     2      5   1.30.  중랑구  중국 우한시       해외 접촉   퇴원
# 6010     1      2   1.24.  강서구  중국 우한시       해외 접촉   퇴원
#
# [6011 rows x 7 columns]

# %%
table[4].head()
# Out:
#                                                  자치구  장소·유형          상호명  \
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
#                                                  자치구  장소·유형          상호명
# 0  이동경로  자치구  장소·유형  상호명  주소(도로명 주소)  노출일시  소독여부 ...    NaN          NaN
# 1                                                자치구  장소·유형          상호명
# 2                                                마포구    NaN           자택
# 3                                                마포구    NaN       타지역 동선
# 4                                                마포구   행정기관  마포구 보건소(자차)
#
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
#    주소(도로명 주소)                    노출일시  소독여부
# 0         NaN                     NaN   NaN
# 1  주소(도로명 주소)                    노출일시  소독여부
# 2         NaN   10. 27(화) ~ 10. 30(금)  소독완료
# 3         NaN  10. 27(화) 13시경 또는 15시경   NaN
# 4         NaN   10. 29(목) 13:30~13:40  소독완료

# %%
df = table[3]
df.shape
# Out:
# (6011, 7)

# %%
last_day = df.loc[3, "확진일"]
last_day = last_day.replace(".", "_")
last_day
# Out:
# '10_30_'

# %%
file_name = f"seoul-covid19-{last_day}.csv"
file_name
# Out:
# 'seoul-covid19-10_30_.csv'

# %%
import pandas as pd

# %%
df.to_csv('seoul-covid19-10_30_.csv', index=False)

# %%
# %ls
# Out:
#  C 드라이브의 볼륨: Windows
#  볼륨 일련 번호: 2C12-07DF
#
#  C:\Users\user\Jupyter_python 디렉터리
#
# 2020-10-31  오후 06:47    <DIR>          .
# 2020-10-31  오후 06:47    <DIR>          ..
# 2020-10-31  오후 06:41    <DIR>          .ipynb_checkpoints
# 2020-10-31  오후 06:47            63,657 2020.10.31 서울시코로나현황.ipynb
# 2020-07-20  오후 02:23    <DIR>          code
# 2020-08-06  오후 02:07    <DIR>          data
# 2020-09-26  오후 11:45    <DIR>          edwith ( edwith.org )
# 2020-10-09  오후 07:59    <DIR>          Kaggle
# 2020-09-15  오후 06:25    <DIR>          MachineHack
# 2020-10-19  오전 11:16    <DIR>          PyTorch 강화학습 심층강화학습 실전입문(도서)
# 2020-10-31  오후 06:48           373,020 seoul-covid19-10_30_.csv
# 2020-10-07  오후 02:49             1,012 TensorFlow.ipynb
# 2020-08-31  오후 07:59             2,757 Untitled1.ipynb
# 2020-09-30  오후 04:19             1,012 Untitled2.ipynb
# 2020-10-11  오후 08:23             2,049 Untitled3.ipynb
# 2020-08-19  오후 12:55    <DIR>          과제
# 2020-10-31  오후 06:24    <DIR>          기환
# 2020-09-26  오후 07:16    <DIR>          나노디그리_프로젝트
# 2020-10-06  오후 01:09    <DIR>          데이콘
# 2020-10-21  오후 02:10    <DIR>          데이터 퀘스트
# 2020-10-28  오후 04:29    <DIR>          러닝스푼즈
# 2020-08-06  오후 02:46            90,177 머신러닝.ipynb
# 2020-09-13  오후 05:39    <DIR>          이력서
# 2020-07-20  오후 02:37             1,589 쥬피터노트북사용법.ipynb
# 2020-08-01  오후 04:30    <DIR>          책
# 2020-09-30  오후 08:19    <DIR>          파이썬_수업
#                8개 파일             535,273 바이트
#               18개 디렉터리  74,395,131,904 바이트 남음

# %%
df=pd.read_csv('seoul-covid19-10_30_.csv')
df.shape
# Out:
# (6011, 7)

# %%
df.head()
# Out:
#      연번     환자     확진일  거주지 여행력         접촉력 퇴원현황
# 0  6011  26507  10.30.  구로구   -  강남구 헬스장 관련  NaN
# 1  6010  26503  10.30.  타시도   -  강남구 헬스장 관련  NaN
# 2  6009  26495  10.30.  구로구   -  강남구 헬스장 관련  NaN
# 3  6008  26492  10.30.  관악구   -   기타 확진자 접촉  NaN
# 4  6007  26468  10.30.  타시도   -    감염경로 조사중  NaN

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %%
a =pd.Series([1,2,3,-1,4]).plot(title='한글')
a

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %%
df['확진일'].value_counts(ascending=False)
# Out:
# 8.29.    167
# 8.27.    160
# 8.26.    157
# 8.18.    151
# 8.15.    146
#         ...
# 4.19.      1
# 4.24.      1
# 2.2.       1
# 5.01.      1
# 4.18.      1
# Name: 확진일, Length: 253, dtype: int64

# %%
df['확진일'].head()
# Out:
# 0    10.30.
# 1    10.30.
# 2    10.30.
# 3    10.30.
# 4    10.30.
# Name: 확진일, dtype: object

# %%
'2020-10-30'
# Out:
# '2020-10-30'

# %%
df['확진일자'] = pd.to_datetime('2020-'+df['확진일'].str.replace('.', '-'))
df
# Out:
#         연번     환자     확진일  거주지     여행력         접촉력 퇴원현황       확진일자
# 0     6011  26507  10.30.  구로구       -  강남구 헬스장 관련  NaN 2020-10-30
# 1     6010  26503  10.30.  타시도       -  강남구 헬스장 관련  NaN 2020-10-30
# 2     6009  26495  10.30.  구로구       -  강남구 헬스장 관련  NaN 2020-10-30
# 3     6008  26492  10.30.  관악구       -   기타 확진자 접촉  NaN 2020-10-30
# 4     6007  26468  10.30.  타시도       -    감염경로 조사중  NaN 2020-10-30
# ...    ...    ...     ...  ...     ...         ...  ...        ...
# 6006     5      9   1.31.  성북구       -       #5 접촉   퇴원 2020-01-31
# 6007     4      7   1.30.  마포구  중국 우한시       해외 접촉   퇴원 2020-01-30
# 6008     3      6   1.30.  종로구       -       #3 접촉   퇴원 2020-01-30
# 6009     2      5   1.30.  중랑구  중국 우한시       해외 접촉   퇴원 2020-01-30
# 6010     1      2   1.24.  강서구  중국 우한시       해외 접촉   퇴원 2020-01-24
#
# [6011 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6011 entries, 0 to 6010
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연번      6011 non-null   int64
#  1   환자      6011 non-null   int64
#  2   확진일     6011 non-null   object
#  3   거주지     6011 non-null   object
#  4   여행력     6011 non-null   object
#  5   접촉력     6011 non-null   object
#  6   퇴원현황    5573 non-null   object
#  7   확진일자    6011 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 375.8+ KB

# %%
df['월'] = df['확진일자'].dt.month
df['주'] = df['확진일자'].dt.week
df.head(1)
# Out:
#      연번     환자     확진일  거주지 여행력         접촉력 퇴원현황       확진일자   월   주
# 0  6011  26507  10.30.  구로구   -  강남구 헬스장 관련  NaN 2020-10-30  10  44

# %%
df['확진일자'].value_counts().plot(figsize=(11,5))

# %%
df['확진일'].value_counts().plot()

# %%
df['월일'] =df['확진일자'].astype(str).map(lambda x: x[-5:])

# %%
df.head()
# Out:
#      연번     환자     확진일  거주지 여행력         접촉력 퇴원현황       확진일자   월   주     월일
# 0  6011  26507  10.30.  구로구   -  강남구 헬스장 관련  NaN 2020-10-30  10  44  10-30
# 1  6010  26503  10.30.  타시도   -  강남구 헬스장 관련  NaN 2020-10-30  10  44  10-30
# 2  6009  26495  10.30.  구로구   -  강남구 헬스장 관련  NaN 2020-10-30  10  44  10-30
# 3  6008  26492  10.30.  관악구   -   기타 확진자 접촉  NaN 2020-10-30  10  44  10-30
# 4  6007  26468  10.30.  타시도   -    감염경로 조사중  NaN 2020-10-30  10  44  10-30

# %%
df['월일'].value_counts().sort_index().plot(figsize=(11,5))

# %%
day_count = df['월일'].value_counts().sort_index()
day_count.plot.bar(figsize=(15,5))

# %%
df['월일'].describe()
# Out:
# count      6011
# unique      252
# top       08-29
# freq        167
# Name: 월일, dtype: object

# %%
day_count.describe()
# Out:
# count    252.000000
# mean      23.853175
# std       32.317497
# min        1.000000
# 25%        6.000000
# 50%       13.500000
# 75%       25.000000
# max      167.000000
# Name: 월일, dtype: float64

# %%
df[df['월일']=='08-29']
# Out:
#         연번     환자    확진일   거주지 여행력            접촉력 퇴원현황       확진일자  월   주  \
# 2098  3913  20100  8.29.   관악구   -     타시도 확진자 접촉   퇴원 2020-08-29  8  35
# 2133  3878  19716  8.29.   동작구   -  성북구 사랑제일교회 관련   퇴원 2020-08-29  8  35
# 2160  3851  19830  8.29.   구로구   -      영등포구 권능교회   퇴원 2020-08-29  8  35
# 2161  3850  19849  8.29.   노원구   -   노원구 빛가온교회 관련   퇴원 2020-08-29  8  35
# 2162  3849  19898  8.29.   금천구   -     타시도 확진자 접촉   퇴원 2020-08-29  8  35
# ...    ...    ...    ...   ...  ..            ...  ...        ... ..  ..
# 2348  3663  19451  8.29.   강남구   -      기타 확진자 접촉   퇴원 2020-08-29  8  35
# 2349  3662  19462  8.29.  동대문구   -    동대문구 sk탁구클럽   퇴원 2020-08-29  8  35
# 2350  3661  19416  8.29.   강북구   -      기타 확진자 접촉   퇴원 2020-08-29  8  35
# 2351  3660  19434  8.29.   강북구   -      기타 확진자 접촉   퇴원 2020-08-29  8  35
# 2356  3655  19330  8.29.   성북구   -  성북구 사랑제일교회 관련   퇴원 2020-08-29  8  35
#
#          월일
# 2098  08-29
# 2133  08-29
# 2160  08-29
# 2161  08-29
# 2162  08-29
# ...     ...
# 2348  08-29
# 2349  08-29
# 2350  08-29
# 2351  08-29
# 2356  08-29
#
# [167 rows x 11 columns]

# %%
day_count.plot.bar(figsize=(15,5), title='일별 발생 현황')

# %%
day_count[-60:].plot.bar(figsize=(15, 14), title="최근 60일 발생현황")

# %%
df['월'].value_counts().sort_index().plot(figsize=(11,5))

# %%
week_count = df['주'].value_counts().sort_index()
week_count.plot()

# %%
week_count_median = week_count.median()
week_count_mean = week_count.mean()
week_count_median, week_count_mean
# Out:
# (78.0, 146.609756097561)

# %%
plt.axhline(week_count_median, color="r", linestyle=":")
plt.axhline(week_count_mean, color="g", linestyle="--")
g = week_count.plot.bar(figsize=(15, 4), rot=0, title="주별 확진 현황")
g

# %%
month_week_count = df.groupby(["월", "주"])["연번"].count()

month_week_count.plot(figsize=(15, 4))

# %%
month_week_count.unstack().T.plot.bar(figsize=(15, 4))

# %%
day_count = df["확진일자"].value_counts().sort_index()

# %%
first_day = day_count.index[0]
last_day = day_count.index[-1]
first_day, last_day
# Out:
# (Timestamp('2020-01-24 00:00:00'), Timestamp('2020-10-30 00:00:00'))

# %%
days = pd.date_range(first_day, last_day)
days
# Out:
# DatetimeIndex(['2020-01-24', '2020-01-25', '2020-01-26', '2020-01-27',
#                '2020-01-28', '2020-01-29', '2020-01-30', '2020-01-31',
#                '2020-02-01', '2020-02-02',
#                ...
#                '2020-10-21', '2020-10-22', '2020-10-23', '2020-10-24',
#                '2020-10-25', '2020-10-26', '2020-10-27', '2020-10-28',
#                '2020-10-29', '2020-10-30'],
#               dtype='datetime64[ns]', length=281, freq='D')

# %%
df_days = pd.DataFrame({"연월일": days})
df_days.head()
# Out:
#          연월일
# 0 2020-01-24
# 1 2020-01-25
# 2 2020-01-26
# 3 2020-01-27
# 4 2020-01-28

# %%
day_count = df["확진일자"].value_counts().sort_index()
day_count.head()
# Out:
# 2020-01-24    1
# 2020-01-30    3
# 2020-01-31    3
# 2020-02-02    1
# 2020-02-05    2
# Name: 확진일자, dtype: int64

# %%
df_day_count = day_count.reset_index()

# %%
df_day_count.columns = ["확진일자", "확진수"]
df_day_count.head(3)
# Out:
#         확진일자  확진수
# 0 2020-01-24    1
# 1 2020-01-30    3
# 2 2020-01-31    3

# %%
df_all_days = df_days.merge(df_day_count, 
                            left_on="연월일", 
                            right_on="확진일자", 
                            how="left")
df_all_days = df_all_days[["연월일", "확진수"]]
df_all_days.head()
# Out:
#          연월일  확진수
# 0 2020-01-24  1.0
# 1 2020-01-25  NaN
# 2 2020-01-26  NaN
# 3 2020-01-27  NaN
# 4 2020-01-28  NaN

# %%
df_all_days["확진수"] = df_all_days["확진수"].fillna(0).astype(int)
df_all_days.head(3)
# Out:
#          연월일  확진수
# 0 2020-01-24    1
# 1 2020-01-25    0
# 2 2020-01-26    0

# %%
df_all_days["일자"] = df_all_days["연월일"].astype(str).map(lambda x : x[-5:])
df_all_days
# Out:
#            연월일  확진수     일자
# 0   2020-01-24    1  01-24
# 1   2020-01-25    0  01-25
# 2   2020-01-26    0  01-26
# 3   2020-01-27    0  01-27
# 4   2020-01-28    0  01-28
# ..         ...  ...    ...
# 276 2020-10-26   21  10-26
# 277 2020-10-27   31  10-27
# 278 2020-10-28   31  10-28
# 279 2020-10-29   52  10-29
# 280 2020-10-30   46  10-30
#
# [281 rows x 3 columns]

# %%
df_all_days["누적확진"] = df_all_days["확진수"].cumsum()
df_all_days[["확진수", "누적확진"]].head(10)
# Out:
#    확진수  누적확진
# 0    1     1
# 1    0     1
# 2    0     1
# 3    0     1
# 4    0     1
# 5    0     1
# 6    3     4
# 7    3     7
# 8    0     7
# 9    1     8

# %%
df_g = df_all_days[["일자", "확진수", "누적확진"]]
df_g = df_g.set_index("일자")
df_g.plot(figsize=(15, 4))

# %%
df_g["확진수"].plot()
df_g["누적확진"].plot(figsize=(15, 4))

# %%
df_g["확진수"].plot(figsize=(15, 4))

# %%
df_g["누적확진"].plot(figsize=(15, 4))

# %%
np.log(df_g["확진수"] + 1).plot()
np.log(df_g["누적확진"] + 1).plot(figsize=(15, 4))
