# %% [markdown]
# ## 서울시에서 공개한 코로나19 발생동향 분석
# * http://www.seoul.go.kr/coronaV/coronaStatus.do

# %%
# pandas, numpy 라이브러리 로드하기

import pandas as pd
import numpy as np

# %%
# file_name 변수에 read_html 로 저장한 파일명을 지정해 줍니다.
file_name = f"seoul_covid_7_29_.csv"
file_name
# Out:
# 'seoul_covid_7_29_.csv'

# %% [markdown]
# * CSV 파일 다운로드 : https://bit.ly/seoul-covid19-csv

# %%
# read_csv 로 csv 파일을 불러와 주세요.
df = pd.read_csv(file_name)
df.shape
# Out:
# (1574, 7)

# %%
# "연번"을 기준으로 역순으로 정렬합니다.
# asc 누르고 TAB 누르면 자동완성
df = df.sort_values(by ="연번", ascending=False)
df.shape
# Out:
# (1574, 7)

# %%
# head 로 미리보기를 합니다.
df.head()
# Out:
#      연번     환자    확진일  거주지  여행력         접촉력   조치사항
# 0  1574  14172  7.26.  송파구    -  송파구 확진자 접촉  서울의료원
# 1  1573  14173  7.26.  강동구   미국    해외 접촉 추정  보라매병원
# 2  1572  14165  7.26.  종로구    -  송파구 확진자 접촉  서울의료원
# 3  1571  14175  7.26.  관악구  필리핀    해외 접촉 추정  보라매병원
# 4  1570  14171  7.26.  용산구  이라크    해외 접촉 추정  서울의료원

# %%
# tail 로 미리보기를 합니다.

df.tail()
# Out:
#       연번  환자    확진일  거주지     여행력    접촉력         조치사항
# 1569   5   9  1.31.  성북구       -  #5 접촉    서울의료원(퇴원)
# 1570   4   7  1.30.  마포구  중국 우한시  해외 접촉    서울의료원(퇴원)
# 1571   3   6  1.30.  종로구       -  #3 접촉  서울대학교병원(퇴원)
# 1572   2   5  1.30.  중랑구  중국 우한시  해외 접촉    서울의료원(퇴원)
# 1573   1   2  1.24.  강서구  중국 우한시  해외 접촉  국립중앙의료원(퇴원)

# %% [markdown]
# ## 시각화 도구 불러오기

# %%
# matplotlib.pyplot 을 통해 한글폰트를 설정합니다.
# plt.style.use 로 "fivethirtyeight" 스타일을 사용해 봅니다.

import matplotlib.pyplot as plt

# 한글 나오게 설정, -안되는거 설정

plt.rc("font", family="Malgun Gothic")
plt.rc("axes", unicode_minus=False)

# %%
pd.Series([1,4,5,-7,6]).plot(title = "한글제목")

# %% [markdown]
# ### 시각화 선명하게 설정하기

# %%
# retina 디스플레이가 지원되는 환경에서 시각화의 폰트가 좀 더 선명해 보입니다.

from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %% [markdown]
# ## 확진일

# %%
# 확진일의 빈도수를 봅니다. 어느 날짜에 가장 많이 확진이 되었는지 봅니다.

df
# Out:
#         연번     환자    확진일  거주지     여행력         접촉력         조치사항
# 0     1574  14172  7.26.  송파구       -  송파구 확진자 접촉        서울의료원
# 1     1573  14173  7.26.  강동구      미국    해외 접촉 추정        보라매병원
# 2     1572  14165  7.26.  종로구       -  송파구 확진자 접촉        서울의료원
# 3     1571  14175  7.26.  관악구     필리핀    해외 접촉 추정        보라매병원
# 4     1570  14171  7.26.  용산구     이라크    해외 접촉 추정        서울의료원
# ...    ...    ...    ...  ...     ...         ...          ...
# 1569     5      9  1.31.  성북구       -       #5 접촉    서울의료원(퇴원)
# 1570     4      7  1.30.  마포구  중국 우한시       해외 접촉    서울의료원(퇴원)
# 1571     3      6  1.30.  종로구       -       #3 접촉  서울대학교병원(퇴원)
# 1572     2      5  1.30.  중랑구  중국 우한시       해외 접촉    서울의료원(퇴원)
# 1573     1      2  1.24.  강서구  중국 우한시       해외 접촉  국립중앙의료원(퇴원)
#
# [1574 rows x 7 columns]

# %%
df["확진일"].value_counts().head(10)
# Out:
# 3.10.    46
# 6.12.    30
# 6.06.    29
# 6.05.    27
# 3.9.     26
# 5.27.    25
# 6.11.    25
# 3.31.    24
# 6.17.    24
# 3.29.    22
# Name: 확진일, dtype: int64

# %%
# "확진일" 컬럼의 데이터가 날짜 형태가 아니라 문자형태 입니다.

df["확진일"].head(1)
# Out:
# 0    7.26.
# Name: 확진일, dtype: object

# %%
# 데이터 타입을 변경해서 날짜형태로 변환합니다.
# 판다스의 to_datetime 을 사용해서 날짜 타입으로 변경할 수 있습니다.
# 연도가 없기 때문에 2020년을 날짜에 추가하고 "-" 문자로 날짜를 연결해 줍니다.


df["확진일자"]=  pd.to_datetime("2020-"+df["확진일"].str.replace(".", "-"))
df.head()
# Out:
#      연번     환자    확진일  거주지  여행력         접촉력   조치사항       확진일자
# 0  1574  14172  7.26.  송파구    -  송파구 확진자 접촉  서울의료원 2020-07-26
# 1  1573  14173  7.26.  강동구   미국    해외 접촉 추정  보라매병원 2020-07-26
# 2  1572  14165  7.26.  종로구    -  송파구 확진자 접촉  서울의료원 2020-07-26
# 3  1571  14175  7.26.  관악구  필리핀    해외 접촉 추정  보라매병원 2020-07-26
# 4  1570  14171  7.26.  용산구  이라크    해외 접촉 추정  서울의료원 2020-07-26

# %%
# 월만 추출합니다.

df["월"] = df["확진일자"].dt.month
df.head(1)
# Out:
#      연번     환자    확진일  거주지 여행력         접촉력   조치사항       확진일자  월
# 0  1574  14172  7.26.  송파구   -  송파구 확진자 접촉  서울의료원 2020-07-26  7

# %%
# 해당 연도의 몇번째 "주"인지 추출합니다.

df["주"] = df["확진일자"].dt.week
df.head(1)
# Out:
#      연번     환자    확진일  거주지 여행력         접촉력   조치사항       확진일자  월   주
# 0  1574  14172  7.26.  송파구   -  송파구 확진자 접촉  서울의료원 2020-07-26  7  30

# %% [markdown]
# ### 선그래프 그리기
# [Visualization — pandas documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html)

# %%
# 확진일자로 선그래프를 그립니다.

df["확진일자"].value_counts().plot(figsize = (15,4))

# %% [markdown]
# ### 선그래프에 값 표시하기

# %%
# 일자별 확진자수를 선그래프로 그립니다.
# 연도는 모두 2020년이기 때문에 월일만 표기되도록 슬라이싱을 사용해 "월일" 컬럼을 만듭니다.
# 위에는 데이터타임이 날짜 이지만 아래는 아니기떄문에 

df["확진일"].value_counts().plot(figsize = (15,4))

# %% [markdown]
#  lambda 익명함수

# %%
df["월일"] = df["확진일자"].astype(str).map(lambda x:x[-5:])
df["월일"].value_counts().sort_index().plot(figsize = (15,4))

# %%
df["월일"] = df["확진일자"].astype(str).map(lambda x:x[-5:])
df["월일"].value_counts().sort_index().plot.bar(figsize = (15,4))

# %% [markdown]
# 다르게 나오는 이유 라인은 연속형이라는 가정하에 하고
# 막대 그래프는 빈도수와 범주형 데이터라는 가정하에 한다.
#
# 라인: 연속된 숫자
# 막대드래프: 범주형 그래프

# %% [markdown]
# ### 확진자가 가장 많이 나온 날

# %%
# describe 를 통해 일자별 확진자수를 describe를 통해 요약해 봅니다.

df["월일"].describe()
# Out:
# count      1574
# unique      156
# top       03-10
# freq         46
# Name: 월일, dtype: object

# %%
day_count = df["월일"].value_counts().sort_index()
day_count.plot.bar(figsize = (15,4))

# %%
# 확진자가 가장 많았던 날을 찾습니다.
day_count.describe()
# Out:
# count    156.000000
# mean      10.089744
# std        7.479324
# min        1.000000
# 25%        4.000000
# 50%        8.000000
# 75%       14.250000
# max       46.000000
# Name: 월일, dtype: float64

# %%
# 확진자가 가장 많았던 날의 발생이력을 찾습니다.
df[df["월일"]=="03-10"]
# Out:
#        연번    환자    확진일   거주지       여행력           접촉력         조치사항       확진일자  \
# 1372  202  7567  3.10.   노원구         -      콜센터직원 접촉    서울의료원(퇴원) 2020-03-10
# 1373  201  7711  3.10.   노원구         -      콜센터직원 접촉    서울의료원(퇴원) 2020-03-10
# 1374  200  7555  3.10.   구로구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1375  199  7725  3.10.   양천구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1376  198  7539  3.10.   양천구         -      콜센터직원 접촉     서남병원(퇴원) 2020-03-10
# 1377  197  7524  3.10.   양천구         -      콜센터직원 접촉    서울의료원(퇴원) 2020-03-10
# 1378  196  7619  3.10.   양천구         -      콜센터직원 접촉    서울의료원(퇴원) 2020-03-10
# 1379  195  7795  3.10.   관악구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1380  194  7787  3.10.   관악구         -      콜센터직원 접촉     서남병원(퇴원) 2020-03-10
# 1381  193  7826  3.10.   관악구         -      콜센터직원 접촉     서남병원(퇴원) 2020-03-10
# 1382  192  7800  3.10.   관악구         -      콜센터직원 접촉    서울의료원(퇴원) 2020-03-10
# 1383  191  7647  3.10.   은평구  프랑스, 스페인  #6959 접촉(추정)     서북병원(퇴원) 2020-03-10
# 1384  190  7588  3.10.   마포구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1385  189  7536  3.10.  동대문구         -       동대문구 관련  국립중앙의료원(퇴원) 2020-03-10
# 1386  188  7561  3.10.  동대문구         -  #7280 접촉(추정)  국립중앙의료원(퇴원) 2020-03-10
# 1387  187  7637  3.10.   금천구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1388  186  7630  3.10.  영등포구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1389  185  7742  3.10.   마포구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1390  184  7823  3.10.   마포구         -    구로구 콜센터 관련  서울대학교병원(퇴원) 2020-03-10
# 1391  183  7840  3.10.   마포구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1392  182  7611  3.10.   동작구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1393  181  7528  3.10.   구로구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1394  180  7520  3.10.   구로구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1395  179  7584  3.10.   구로구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1396  178  7602  3.10.  동대문구         -       동대문구 관련    서울의료원(퇴원) 2020-03-10
# 1397  177  7523  3.10.   구로구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1398  176  7564  3.10.  영등포구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1399  175  7695  3.10.   강서구         -    구로구 콜센터 관련     서북병원(퇴원) 2020-03-10
# 1400  174  7571  3.10.  동대문구         -       동대문구 관련    서울의료원(퇴원) 2020-03-10
# 1401  173  7731  3.10.   강서구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1402  172  7642  3.10.   양천구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1403  171  7638  3.10.   양천구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1404  170  7734  3.10.   관악구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1405  169  7712  3.10.   양천구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1406  168  7653  3.10.  영등포구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1407  167  7622  3.10.  영등포구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1408  166  7685  3.10.  영등포구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1409  165  7624  3.10.   송파구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1410  164  7573  3.10.   은평구         -  #7500 접촉(추정)    서울의료원(퇴원) 2020-03-10
# 1411  163  7723  3.10.   강서구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1412  162  7727  3.10.   강서구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1413  161  7603  3.10.   관악구         -    구로구 콜센터 관련    보라매병원(퇴원) 2020-03-10
# 1414  160  7644  3.10.   관악구         -    구로구 콜센터 관련    보라매병원(퇴원) 2020-03-10
# 1415  159  7666  3.10.   관악구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1416  158  7721  3.10.   동작구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1417  157  7525  3.10.   동작구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
#
#       월   주     월일
# 1372  3  11  03-10
# 1373  3  11  03-10
# 1374  3  11  03-10
# 1375  3  11  03-10
# 1376  3  11  03-10
# 1377  3  11  03-10
# 1378  3  11  03-10
# 1379  3  11  03-10
# 1380  3  11  03-10
# 1381  3  11  03-10
# 1382  3  11  03-10
# 1383  3  11  03-10
# 1384  3  11  03-10
# 1385  3  11  03-10
# 1386  3  11  03-10
# 1387  3  11  03-10
# 1388  3  11  03-10
# 1389  3  11  03-10
# 1390  3  11  03-10
# 1391  3  11  03-10
# 1392  3  11  03-10
# 1393  3  11  03-10
# 1394  3  11  03-10
# 1395  3  11  03-10
# 1396  3  11  03-10
# 1397  3  11  03-10
# 1398  3  11  03-10
# 1399  3  11  03-10
# 1400  3  11  03-10
# 1401  3  11  03-10
# 1402  3  11  03-10
# 1403  3  11  03-10
# 1404  3  11  03-10
# 1405  3  11  03-10
# 1406  3  11  03-10
# 1407  3  11  03-10
# 1408  3  11  03-10
# 1409  3  11  03-10
# 1410  3  11  03-10
# 1411  3  11  03-10
# 1412  3  11  03-10
# 1413  3  11  03-10
# 1414  3  11  03-10
# 1415  3  11  03-10
# 1416  3  11  03-10
# 1417  3  11  03-10

# %% [markdown]
# ### 막대그래프 그리기

# %%
# 선그래프로 그렸던 그래프를 막대그래프로 그립니다.

day_count.plot.bar(figsize = (15,4), title= "일별발생현황")

# %% [markdown]
# ### 최근 데이터만 슬라이싱으로 나눠 그리기

# %%
# 슬라이싱을 통해 최근 데이터만 그립니다.

day_count[-60:].plot.bar(figsize = (15,4), title="최근 60일 발생현황")

# %% [markdown]
# ### 월별 확진자 수 그리기

# %%
# 월별 확진자수에 대한 빈도수를 구해서 시각화 합니다.

df["월"].value_counts().sort_index().plot(figsize = (15,4))

# %% [markdown]
# ### 주단위 확진자수 그리기

# %%
# 주별로 빈도수를 구합니다.


week_count = df["주"].value_counts().sort_index()
week_count.plot(figsize = (15,4), title="주변 발생 현황")

# %%
week_count_median = week_count.median()
week_count_mean = week_count.mean()

week_count_median, week_count_mean
# Out:
# (51.0, 58.2962962962963)

# %%
# 주단위 빈도수 막대그래프로 그리기
plt.axhline(week_count_median, color = "r", linestyle=":")
plt.axhline(week_count_mean, color = "g", linestyle="--")
g = week_count.plot.bar(figsize = (15,4), rot= 0, title= "주변 확진 현황")
g

# %% [markdown]
#  rot : x축의 회전 각도를 의미한다.

# %% [markdown]
# 문구를 없애고 싶으면 번수에 담아줘라

# %% [markdown]
# ### 월-주 함께 그리기

# %%
# 월-주 를 함께 그래프에 표현하기
month_week_count = df.groupby(["월", "주"])["연번"].count()
month_week_count
# Out:
# 월  주
# 1  4       1
#    5       6
# 2  5       1
#    6       4
#    7       2
#    8      17
#    9      56
# 3  9       6
#    10     37
#    11    124
#    12     76
#    13    105
#    14     43
# 4  14     85
#    15     47
#    16     15
#    17      4
#    18      5
# 5  18      3
#    19     51
#    20     48
#    21     39
#    22     87
# 6  23    134
#    24    125
#    25    106
#    26     78
#    27     17
# 7  27     50
#    28     57
#    29     48
#    30     97
# Name: 연번, dtype: int64

# %%
month_week_count.plot(figsize = (15,4))

# %%
month_week_count.unstack().T.plot.bar(figsize=(15, 4))

# %%
#
month_week_count = df.groupby(["월","주"])["연번"].count()
month_week_count.plot(figsize = (15,4))

# %% [markdown]
# ## 모든 날짜를 행에 만들어 주기
# * 확진자가 없는 날의 데이터도 만들어 줍니다.

# %%
# 첫 확진일 부터 마지막 확진일까지 가져옵니다.
# 데이터프레임의 첫번째 날짜는 first_day 에 마지막 날짜는 last_day 에 담습니다.

day_count = df["확진일자"].value_counts().sort_index()

# %%
fist_day = day_count.index[0]
last_day = day_count.index[-1]
fist_day,  last_day
# Out:
# (Timestamp('2020-01-24 00:00:00'), Timestamp('2020-07-26 00:00:00'))

# %%
# pd.date_range 를 통해 시작하는 날짜부터 끝나는 날짜까지의 
# DatetimeIndex 를 만들고 days 라는 변수에 저장합니다.

days = pd.date_range(fist_day,  last_day)
days
# Out:
# DatetimeIndex(['2020-01-24', '2020-01-25', '2020-01-26', '2020-01-27',
#                '2020-01-28', '2020-01-29', '2020-01-30', '2020-01-31',
#                '2020-02-01', '2020-02-02',
#                ...
#                '2020-07-17', '2020-07-18', '2020-07-19', '2020-07-20',
#                '2020-07-21', '2020-07-22', '2020-07-23', '2020-07-24',
#                '2020-07-25', '2020-07-26'],
#               dtype='datetime64[ns]', length=185, freq='D')

# %% [markdown]
# pd.date_range 함수를 쓰면 모든 날짜/시간을 일일히 입력할 필요없이 시작일과 종료일 또는 시작일과 기간을 입력하면 범위 내의 인덱스를 생성해 준다.

# %%
# days 변수의 값으로 "연월일" 이라는 컬럼이름을 갖는 데이터프레임을 만듭니다.

# days.to_frame()
# pd.DataFrame(days)
df_days = pd.DataFrame({"연월일": days})
df_days.head()
# Out:
#          연월일
# 0 2020-01-24
# 1 2020-01-25
# 2 2020-01-26
# 3 2020-01-27
# 4 2020-01-28

# %%
# 확진일자별로 빈도수 구하기

day_count =df["확진일자"].value_counts().sort_index()
day_count.head()
# Out:
# 2020-01-24    1
# 2020-01-30    3
# 2020-01-31    3
# 2020-02-02    1
# 2020-02-05    2
# Name: 확진일자, dtype: int64

# %%
# 확진일자별로 빈도수 구한 내용을 데이터프레임으로 변환하기

df_day_count = day_count.reset_index()

# %%
# value_counts 결과의 컬럼명을 "확진수" 로 바꾸기

df_day_count.columns =["확진일자", "확진수"]
df_day_count.head()
# Out:
#         확진일자  확진수
# 0 2020-01-24    1
# 1 2020-01-30    3
# 2 2020-01-31    3
# 3 2020-02-02    1
# 4 2020-02-05    2

# %% [markdown]
# ### merge 를 통해 전체 확진일자 만들기
# * 이미지 출처 및 Pandas 공식문서 보기 : [How to combine data from multiple tables? — pandas documentation](https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/08_combine_dataframes.html#join-tables-using-a-common-identifier)
#
# <img src="https://pandas.pydata.org/pandas-docs/stable/_images/08_merge_left.svg">

# %%
# 확진자가 없는 날도 일자에 표현이 되도록 전체 일자와 확진 데이터를 merge 로 합쳐줍니다.

df_all_days = df_days.merge(df_day_count, 
                            left_on = "연월일", 
                            right_on = "확진일자",
                            how= "left")
df_all_days = df_all_days[["연월일","확진수"]]
df_all_days
# Out:
#            연월일   확진수
# 0   2020-01-24   1.0
# 1   2020-01-25   NaN
# 2   2020-01-26   NaN
# 3   2020-01-27   NaN
# 4   2020-01-28   NaN
# ..         ...   ...
# 180 2020-07-22  11.0
# 181 2020-07-23  21.0
# 182 2020-07-24  11.0
# 183 2020-07-25   7.0
# 184 2020-07-26   9.0
#
# [185 rows x 2 columns]

# %% [markdown]
# ## 누적 확진자 수 구하기

# %%
# 확진수를 fillna를 통해 결측치를 0으로 채워주고 누적해서 더해줍니다.

df_all_days["확진수"] = df_all_days["확진수"].fillna(0).astype(int)
df_all_days
# Out:
#            연월일  확진수
# 0   2020-01-24    1
# 1   2020-01-25    0
# 2   2020-01-26    0
# 3   2020-01-27    0
# 4   2020-01-28    0
# ..         ...  ...
# 180 2020-07-22   11
# 181 2020-07-23   21
# 182 2020-07-24   11
# 183 2020-07-25    7
# 184 2020-07-26    9
#
# [185 rows x 2 columns]

# %%
# 연도를 제외하고 월-일로 "일자" 컬럼 만들기

df_all_days["일자"] = df_all_days["연월일"].astype(str).map(lambda x : x[-5:])
df_all_days
# Out:
#            연월일  확진수     일자
# 0   2020-01-24    1  01-24
# 1   2020-01-25    0  01-25
# 2   2020-01-26    0  01-26
# 3   2020-01-27    0  01-27
# 4   2020-01-28    0  01-28
# ..         ...  ...    ...
# 180 2020-07-22   11  07-22
# 181 2020-07-23   21  07-23
# 182 2020-07-24   11  07-24
# 183 2020-07-25    7  07-25
# 184 2020-07-26    9  07-26
#
# [185 rows x 3 columns]

# %%
# "확진수", "누적확진" 컬럼을 갖는 데이터프레임을 만듭니다.
df_all_days["누적확진"] = df_all_days["확진수"].cumsum()
df_all_days[["확진수", "누적확진"]].head(10)
# Out:
#    확진수  누적확진
# 0    1     1
# 1    0     1
# 2    0     1
# 3    0     1
# 4    0     1
# 5    0     1
# 6    3     4
# 7    3     7
# 8    0     7
# 9    1     8

# %%
df_all_days.tail()
# Out:
#            연월일  확진수     일자  누적확진
# 180 2020-07-22   11  07-22  1526
# 181 2020-07-23   21  07-23  1547
# 182 2020-07-24   11  07-24  1558
# 183 2020-07-25    7  07-25  1565
# 184 2020-07-26    9  07-26  1574

# %% [markdown]
# ### 데이터프레임으로 그리기

# %%
# 데이터프레임으로 확진수와 누적확진을 선그래프로 그립니다.

df_g = df_all_days[["일자", "확진수","누적확진"]]
df_g = df_g.set_index("일자")
df_g.plot(figsize=(15,4))

# %% [markdown]
# ### 시리즈로 그리기

# %%
# 시리즈로 2개의 그래프 그리기

df_g["확진수"].plot()
df_g["누적확진"].plot(figsize=(15,4))

# %% [markdown]
# ### 확진수만 따로 그리기

# %%
# 누적확진수와 확진수와 차이가 크면 제대로 보이지 않기 때문에 확진수만 그립니다.
df_g["확진수"].plot(figsize=(15,4))

# %% [markdown]
# ### 누적확진만 따로 그리기

# %%
# 누적확진만 따로 그립니다.

df_g["누적확진"].plot(figsize=(15,4))

# %% [markdown]
# ### 로그스케일
# * 차이가 너무 커서 그래프가 자세히 보이지 않을때 로그스케일로 표현하면 차이가 큰 값의 스케일을 조정해주게 됩니다.

# %%
np.log(df_g["확진수"]+ 1).plot()
np.log(df_g["누적확진"]+ 1).plot(figsize=(15,4))

# %% [markdown]
# ### 확진월과 요일 구하기

# %%
df
# Out:
#         연번     환자    확진일  거주지     여행력         접촉력         조치사항       확진일자  월  \
# 0     1574  14172  7.26.  송파구       -  송파구 확진자 접촉        서울의료원 2020-07-26  7
# 1     1573  14173  7.26.  강동구      미국    해외 접촉 추정        보라매병원 2020-07-26  7
# 2     1572  14165  7.26.  종로구       -  송파구 확진자 접촉        서울의료원 2020-07-26  7
# 3     1571  14175  7.26.  관악구     필리핀    해외 접촉 추정        보라매병원 2020-07-26  7
# 4     1570  14171  7.26.  용산구     이라크    해외 접촉 추정        서울의료원 2020-07-26  7
# ...    ...    ...    ...  ...     ...         ...          ...        ... ..
# 1569     5      9  1.31.  성북구       -       #5 접촉    서울의료원(퇴원) 2020-01-31  1
# 1570     4      7  1.30.  마포구  중국 우한시       해외 접촉    서울의료원(퇴원) 2020-01-30  1
# 1571     3      6  1.30.  종로구       -       #3 접촉  서울대학교병원(퇴원) 2020-01-30  1
# 1572     2      5  1.30.  중랑구  중국 우한시       해외 접촉    서울의료원(퇴원) 2020-01-30  1
# 1573     1      2  1.24.  강서구  중국 우한시       해외 접촉  국립중앙의료원(퇴원) 2020-01-24  1
#
#        주     월일
# 0     30  07-26
# 1     30  07-26
# 2     30  07-26
# 3     30  07-26
# 4     30  07-26
# ...   ..    ...
# 1569   5  01-31
# 1570   5  01-30
# 1571   5  01-30
# 1572   5  01-30
# 1573   4  01-24
#
# [1574 rows x 11 columns]

# %% [markdown]
# https://datascienceschool.net/view-notebook/465066ac92ef4da3b0aba32f76d9750a/
#
# datetime 패키지

# %%
df["요일"] = df["확진일자"].dt.dayofweek
df[["확진일자", "요일"]].head()
# Out:
#         확진일자  요일
# 0 2020-07-26   6
# 1 2020-07-26   6
# 2 2020-07-26   6
# 3 2020-07-26   6
# 4 2020-07-26   6

# %%
weekday_name="월 화 수 목 금 토 일"
weekday_name = weekday_name.split()
weekday_name
# Out:
# ['월', '화', '수', '목', '금', '토', '일']

# %%
weekday_name[0]
# Out:
# '월'

# %%
df["요일"].map(lambda x :x)
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 1569    4
# 1570    3
# 1571    3
# 1572    3
# 1573    4
# Name: 요일, Length: 1574, dtype: int64

# %%
df["요일명"] = df["요일"].map(lambda x :weekday_name[x])
df[["확진일자", "요일", "요일명"]].head()
# Out:
#         확진일자  요일 요일명
# 0 2020-07-26   6   일
# 1 2020-07-26   6   일
# 2 2020-07-26   6   일
# 3 2020-07-26   6   일
# 4 2020-07-26   6   일

# %% [markdown]
# ## 요일별 확진 수

# %%
g = df.groupby(["월", "요일명"])["연번"].count()
g.index
# Out:
# MultiIndex([(1, '금'),
#             (1, '목'),
#             (2, '금'),
#             (2, '목'),
#             (2, '수'),
#             (2, '월'),
#             (2, '일'),
#             (2, '토'),
#             (2, '화'),
#             (3, '금'),
#             (3, '목'),
#             (3, '수'),
#             (3, '월'),
#             (3, '일'),
#             (3, '토'),
#             (3, '화'),
#             (4, '금'),
#             (4, '목'),
#             (4, '수'),
#             (4, '월'),
#             (4, '일'),
#             (4, '토'),
#             (4, '화'),
#             (5, '금'),
#             (5, '목'),
#             (5, '수'),
#             (5, '월'),
#             (5, '일'),
#             (5, '토'),
#             (5, '화'),
#             (6, '금'),
#             (6, '목'),
#             (6, '수'),
#             (6, '월'),
#             (6, '일'),
#             (6, '토'),
#             (6, '화'),
#             (7, '금'),
#             (7, '목'),
#             (7, '수'),
#             (7, '월'),
#             (7, '일'),
#             (7, '토'),
#             (7, '화')],
#            names=['월', '요일명'])

# %%
# 월별, 요일별 확진수를 groupby로 구하기

g = df.groupby(["월", "요일명"])["연번"].count()
g = g.unstack()
g = g.fillna(0).astype(int)
g =g[weekday_name]
g
# Out:
# 요일명   월   화   수   목   금   토   일
# 월
# 1     0   0   0   3   4   0   0
# 2     4  16  14  19  11   9   7
# 3    69  89  46  44  48  45  50
# 4    16  17  28  27  26  22  20
# 5    27  36  34  34  32  36  29
# 6    55  67  66  75  90  70  37
# 7    31  33  39  49  32  40  28

# %%
#g = df.groupby(["월", "요일명"])["연번"].count().unstack()
#g = g.fillna(0).astype(int)
#g

# %%
# 숫자로 표현된 요일을 문자로 바꿔주기 위해 split 을 통해 문자를 리스트로 변경합니다.
# dayofweek

# %%
# 컬럼의 이름을 한글요일명으로 변경해 줍니다.

g.style.background_gradient(cmap= "Greens")
# Out:
# <style  type="text/css" >
#     #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row0_col0 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row0_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row0_col2 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row0_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row0_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row0_col5 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row0_col6 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row1_col0 {
#             background-color:  #eff9ec;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row1_col1 {
#             background-color:  #d8f0d2;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row1_col2 {
#             background-color:  #d0edca;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row1_col3 {
#             background-color:  #ceecc8;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row1_col4 {
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row1_col5 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row1_col6 {
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row2_col0 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row2_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row2_col2 {
#             background-color:  #2f984f;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row2_col3 {
#             background-color:  #58b668;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row2_col4 {
#             background-color:  #70c274;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row2_col5 {
#             background-color:  #3da65a;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row2_col6 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row3_col0 {
#             background-color:  #cbebc5;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row3_col1 {
#             background-color:  #d6efd0;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row3_col2 {
#             background-color:  #90d18d;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row3_col3 {
#             background-color:  #aedea7;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row3_col4 {
#             background-color:  #c6e8bf;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row3_col5 {
#             background-color:  #b4e1ad;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row3_col6 {
#             background-color:  #98d594;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row4_col0 {
#             background-color:  #9bd696;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row4_col1 {
#             background-color:  #97d492;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row4_col2 {
#             background-color:  #6ec173;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row4_col3 {
#             background-color:  #8dd08a;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row4_col4 {
#             background-color:  #b0dfaa;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row4_col5 {
#             background-color:  #6ec173;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row4_col6 {
#             background-color:  #53b466;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row5_col0 {
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row5_col1 {
#             background-color:  #228a44;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row5_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row5_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row5_col4 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row5_col5 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row5_col6 {
#             background-color:  #258d47;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row6_col0 {
#             background-color:  #86cc85;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row6_col1 {
#             background-color:  #a3da9d;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row6_col2 {
#             background-color:  #4eb264;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row6_col3 {
#             background-color:  #3ea75a;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row6_col4 {
#             background-color:  #b0dfaa;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row6_col5 {
#             background-color:  #56b567;
#             color:  #000000;
#         }    #T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row6_col6 {
#             background-color:  #5bb86a;
#             color:  #000000;
#         }</style><table id="T_8c70d718_d3b6_11ea_b839_f8ac65c64f39" ><thead>    <tr>        <th class="index_name level0" >요일명</th>        <th class="col_heading level0 col0" >월</th>        <th class="col_heading level0 col1" >화</th>        <th class="col_heading level0 col2" >수</th>        <th class="col_heading level0 col3" >목</th>        <th class="col_heading level0 col4" >금</th>        <th class="col_heading level0 col5" >토</th>        <th class="col_heading level0 col6" >일</th>    </tr>    <tr>        <th class="index_name level0" >월</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8c70d718_d3b6_11ea_b839_f8ac65c64f39level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row0_col3" class="data row0 col3" >3</td>
#                         <td id="T_8c70d718_d3b6_11ea_b839_f8ac65c64f39row0_

# %%
# 큰거 = 진하게 

import seaborn as sns
sns.heatmap(g, cmap="Greens", annot=True)

# %%
# 작은거 =  연하게 

import seaborn as sns
sns.heatmap(g, cmap="Greens_r", annot=True)

# %% [markdown]
# # y축 돌리기
#
# import seaborn as sns
# yplt.yticks(rotation = 0)
#
# sns.heatmap(g, cmap="Greens_r", annot=True)

# %% [markdown]
# # vmax=  숫자 진하기
#
# import seaborn as sns
# sns.heatmap(g, cmap="Greens", annot=True, vmax= 100)

# %% [markdown]
# 확진자가 많을 수록 점점진해진다.

# %% [markdown]
# # style.background_gradient 로 색상을 표현합니다.

# %% [markdown]
# ## 거주지별 확진자

# %%
# 거주지(구별) 확진자의 빈도수를 구하고 시각화 합니다.

gu_count = df["거주지"].value_counts()
gu_count.plot.bar(figsize=(15,5), rot = 90)

# %%
# 구별 확진자의 수를 시각화 합니다.

seoul_gu = gu_count.head(25).index
seoul_gu
# Out:
# Index(['관악구', '강서구', '강남구', '송파구', '구로구', '영등포구', '동작구', '양천구', '도봉구', '은평구',
#        '서초구', '성동구', '용산구', '마포구', '노원구', '강동구', '중랑구', '동대문구', '서대문구', '성북구',
#        '금천구', '종로구', '강북구', '광진구', '중구'],
#       dtype='object')

# %%
# del df["구"]

# %%
# 서울에서 확진판정을 받은 데이터이기 때문에 거주지가 서울이 아닐 수도 있습니다.
# 거주지 별로 서울시에 해당되는 데이터만 따로 가져옵니다.

df[~df["거주지"].isin(seoul_gu)]
# Out:
#         연번     환자    확진일   거주지    여행력         접촉력         조치사항       확진일자  월  \
# 12    1562  14143  7.25.    기타    이라크    해외 접촉 추정       생활치료센터 2020-07-25  7
# 13    1561  14140  7.25.    기타      -  송파구 확진자 접촉        보라매병원 2020-07-25  7
# 28    1546  13964  7.23.   성남시      -    송파구 교회관련       타시도 이관 2020-07-23  7
# 43    1531  13968  7.23.  경기광주      -        확인 중       타시도 이관 2020-07-23  7
# 154   1420  13447  7.12.   고양시      -  강남구 확진자 접촉       타시도 이관 2020-07-12  7
# ...    ...    ...    ...   ...    ...         ...          ...        ... ..
# 1535    39    907  2.25.   평택시      -         확인중   타시도 이관(퇴원) 2020-02-25  2
# 1539    35    847  2.25.   김포시      -         확인중   타시도 이관(퇴원) 2020-02-25  2
# 1556    18    111  2.20.   대구시      -      대구 거주자  국립중앙의료원(퇴원) 2020-02-20  2
# 1562    12     24   2.7.   아산시   우한교민       해외 접촉  국립중앙의료원(퇴원) 2020-02-07  2
# 1566     8     13   2.2.   인천시  우한 교민       해외 접촉  국립중앙의료원(퇴원) 2020-02-02  2
#
#        주     월일  요일 요일명
# 12    30  07-25   5   토
# 13    30  07-25   5   토
# 28    30  07-23   3   목
# 43    30  07-23   3   목
# 154   28  07-12   6   일
# ...   ..    ...  ..  ..
# 1535   9  02-25   1   화
# 1539   9  02-25   1   화
# 1556   8  02-20   3   목
# 1562   6  02-07   4   금
# 1566   5  02-02   6   일
#
# [91 rows x 13 columns]

# %%
gu_count
# Out:
# 관악구     139
# 강서구     102
# 강남구      97
# 송파구      96
# 구로구      90
#        ...
# 부평        1
# 국외거주      1
# 미국        1
# 안산시       1
# 의왕시       1
# Name: 거주지, Length: 61, dtype: int64

# %%
gu_count.loc[seoul_gu]
# Out:
# 관악구     139
# 강서구     102
# 강남구      97
# 송파구      96
# 구로구      90
# 영등포구     71
# 동작구      70
# 양천구      70
# 도봉구      64
# 은평구      63
# 서초구      61
# 성동구      57
# 용산구      54
# 마포구      50
# 노원구      49
# 강동구      48
# 중랑구      44
# 동대문구     44
# 서대문구     41
# 성북구      40
# 금천구      39
# 종로구      28
# 강북구      25
# 광진구      22
# 중구       19
# Name: 거주지, dtype: int64

# %%
# 거주지가 서울이 아닌 지역을 따로 추출합니다.

# %%
# 구를 전처리 하기 쉽게 컬럼으로 변환하기 위해 reset_index 로 변환합니다.

df["지역"] = df["거주지"]
df.head(2)
# Out:
#      연번     환자    확진일  거주지 여행력         접촉력   조치사항       확진일자  월   주     월일  \
# 0  1574  14172  7.26.  송파구   -  송파구 확진자 접촉  서울의료원 2020-07-26  7  30  07-26
# 1  1573  14173  7.26.  강동구  미국    해외 접촉 추정  보라매병원 2020-07-26  7  30  07-26
#
#    요일 요일명   지역
# 0   6   일  송파구
# 1   6   일  강동구

# %%
# 서울에서 확진 받은 사람 중 서울 vs 타지역을 비교해 보기 위해
# "지역"이라는 새로운 컬럼을 만들어 서울지역이 아니라면 "타지역" 이라는 값을 넣어줍니다. 
# .loc[행인덱스]
# .loc[행, 열]
# .loc[조건, 열]

df.loc[~df["거주지"].isin(seoul_gu), "지역"] = "타지역"

# %%
df["지역"] = df["거주지"].map(lambda x : x if x in seoul_gu else "타지역")
df.tail(1)
# Out:
#       연번  환자    확진일  거주지     여행력    접촉력         조치사항       확진일자  월  주     월일  \
# 1573   1   2  1.24.  강서구  중국 우한시  해외 접촉  국립중앙의료원(퇴원) 2020-01-24  1  4  01-24
#
#       요일 요일명   지역
# 1573   4   금  강서구

# %%
# 이름이 있는함수

def find_seoul_gu(x):
    if x in seoul_gu:
        return x 
    else:
        return "타지역"

# %%
# 시리즈와 데이터프레임에 모두 사용가능합니다.

df["지역"] = df["거주지"].apply(find_seoul_gu)

# %%
# 시리즈에서만 사용이 가능하다


df ["지역"] = df["거주지"].map(find_seoul_gu)

# %%
# 위의 방법으로 할수도 있고 아래의 방법으로 만들수도 있습니다.
# 함수 혹은 익명함수를 사용하는 방법으로 "타지역" 값을 만들 수도 있습니다.

df["지역"].value_counts()
# Out:
# 관악구     139
# 강서구     102
# 강남구      97
# 송파구      96
# 타지역      91
# 구로구      90
# 영등포구     71
# 양천구      70
# 동작구      70
# 도봉구      64
# 은평구      63
# 서초구      61
# 성동구      57
# 용산구      54
# 마포구      50
# 노원구      49
# 강동구      48
# 중랑구      44
# 동대문구     44
# 서대문구     41
# 성북구      40
# 금천구      39
# 종로구      28
# 강북구      25
# 광진구      22
# 중구       19
# Name: 지역, dtype: int64

# %%
df.loc[df["지역"] == "타지역", "거주지"].unique()
# Out:
# array(['기타', '성남시', '경기광주', '고양시', '광명시', '대전시', '남양주', '군포시', '의정부',
#        '양산시', '주소불명', '안산시', '수원시', '부천시', '김포시', '인천시', '양주시', '안양',
#        '양평', '구리시', '의왕시', '안양시', '부평', '미국', '화성시', '천안시', '시흥시', '스페인',
#        '용인시', '재외국민', '국외거주', '파주시', '대구시', '경북', '평택시', '아산시'],
#       dtype=object)

# %%
# "지역" 컬럼으로 확진자 빈도수를 구합니다.

seoul_gu_count= df["지역"].value_counts()

# %%
# 위에서 구한 빈도수를 막대그래프로 그립니다.

seoul_gu_count.sort_values().plot.barh(figsize=(8,7))

# %% [markdown]
# ## 접촉력

# %%
# 접촉력 빈도수를 구합니다.

df["접촉력"].value_counts().head(10)
# Out:
# 해외 접촉 추정       314
# 이태원 클럽 관련      139
# 확인 중           136
# 리치웨이 관련        119
# 구로구 콜센터 관련      60
# 타시도 확진자 접촉      49
# 확인중             44
# 요양시설 관련         43
# 양천구 운동시설 관련     43
# 구로구 교회 관련       41
# Name: 접촉력, dtype: int64

# %%
df["접촉력"].value_counts(normalize=True).head(10) * 100
# Out:
# 해외 접촉 추정       19.949174
# 이태원 클럽 관련       8.831004
# 확인 중            8.640407
# 리치웨이 관련         7.560356
# 구로구 콜센터 관련      3.811944
# 타시도 확진자 접촉      3.113088
# 확인중             2.795426
# 요양시설 관련         2.731893
# 양천구 운동시설 관련     2.731893
# 구로구 교회 관련       2.604828
# Name: 접촉력, dtype: float64

# %% [markdown]
# 확인중 = 확인 중 이부분 하기

# %%
# 접촉력의 unique 값만 구합니다.

df["접촉력"].unique()
# Out:
# array(['송파구 확진자 접촉', '해외 접촉 추정', '확인 중', '강서구 요양시설관련', '은평구 확진자 접촉',
#        '송파구 교회관련', '관악구 사무실 관련', '강남구 사무실 K빌딩', '강남구 사무실 관련', '종로구 지인모임',
#        '동작구 확진자 접촉', '타시도 확진자 접촉', '강남역삼동 금융회사', '중구 확진자 접촉',
#        '강남구 확진자 접촉', '확인중', '강서구 요양시설 관련', '성북구 확진자 접촉', '서초구 확진자 접촉',
#        '성동구 확진자 접촉', '영등포구 확진자 접촉', '강남구 이동통신 종사자', '강남구 역삼동 모임',
#        '양천구 확진자 접촉', '강서구 확진자 접촉', '용산구 확진자 접촉', '광진구 확진자 접촉', '왕성교회 관련',
#        '중랑구 일가족 관련', '관악구 확진자 접촉', '종로구 확진자 접촉', '관악구 일가족 관련',
#        '대전 꿈꾸는 교회', '리치웨이 관련', '구로구 확진자 접촉', '금천구 확진자 접촉', '요양시설 관련',
#        '강동구 확진자 접촉', '시청역 관련', '대자연코리아', '의왕 물류센터 관련', '금천구 도정기 회사 관련',
#        '양천구 운동시설 관련', '대전 다단계 관련', '오렌지라이프 관련', '수도권 개척교회 관련',
#        '타시도 확진자 접촉자', '연아나뉴스클래스 관련', '한국대학생선교회 관련', '해외접촉 추정',
#        'kb 생명보험 관련', '부천시 쿠팡 관련', '이태원 클럽 관련', '용인 형제 관련', '삼성화재 관련',
#        '서초구 가족 관련', '안양군포 목회자 관련', '서초구 가족관련', '영등포 학원 관련', '강남구 동인교회 관련',
#        '원어성경연구회 관련', '#11196 접촉', '삼성서울병원 관련', '#10054 접촉', '#9800 접촉',
#        '#10044 접촉', '#9641 접촉', '구로구 교회 관련', '#10407 접촉', '#10015 접촉',
#        '#9364 접촉', '#10377 접촉', '#9287 접촉', '#10142 접촉', '#9912 접촉',
#        '#9765 접촉', '#10115 접촉', '타시도 확진자 접촉(추정)', '#8063 접촉', '#10084 접촉',
#        '#8601 접촉', '#8717 접촉', '#9946 접촉', '콜센터직원 접촉', '#8271 접촉',
#        '#8669 접촉', '#9734 접촉', '#9621 접촉', '#9572 접촉', '#9525 접촉',
#        '#7914 접촉', '#8791 접촉', '#9219 접촉', '#8057 접촉', '#8079 접촉',
#        '#8646 접촉', '#9020 접촉', '#8245 접촉', '#8709 접촉 추정', '#8881 접촉 추정',
#        '구로구 콜센터 관련', '#8486 접촉', '동대문구 관련', '#8196 접촉', '#8138 접촉',
#        '구로구 콜센터 접촉', '#8044 접촉', '해외 접촉', '#7923 접촉', '신천지 추정',
#        '#7573 접축 추정', '#6959 접촉(추정)', '#7280 접촉(추정)', '#7500 접촉(추정)',
#        '#6727 첩촉', '대구 거주', '#6832 접촉자', '#6921접촉자', '#935 접촉자',
#        '#6937 접촉자', '성동구 아파트 관련', '대구 방문', '부동산 중개 법인 관련', '여의도 건설현장 관련',
#        '대구 확진자 접촉', '명성교회 관련', '#794 접촉(추정)', '#2621번 접촉', '#1247 접촉(추정)',
#        '부동산 중개업 관련', '쇼핑몰 관련', '은평구 병원 관련', '경찰병원관련', '서울재생병원 관련',
#        '신천지대구교회 관련', '#794 접촉자', '대구 방문(명성교회)', '#780 접촉(추정)', '#56 접촉',
#        '#136 접촉', '대구 거주자', '#6 접촉(추정)', '#30 접촉', '#29 접촉', '#83 접촉',
#        '#6 접촉', '#5 접촉', '#3 접촉'], dtype=object)

# %%
# "확인" 이 들어가는 접촉력만 찾습니다.

df.loc[df["접촉력"].str.contains("확인"), "접촉력"].unique()
# Out:
# array(['확인 중', '확인중'], dtype=object)

# %%
# '확인 중', '확인중' => "확인 중" 으로 변경합니다.

df.loc[df["접촉력"].str.contains("확인"), "접촉력"] = "확인 중"

# %%
# "확인" 이 들어가는 접촉력만 찾습니다.

# %%
# 접촉력 빈도수를 시각화 합니다.

contact_count = df["접촉력"].value_counts()
contact_count
# Out:
# 해외 접촉 추정       314
# 확인 중           180
# 이태원 클럽 관련      139
# 리치웨이 관련        119
# 구로구 콜센터 관련      60
#               ...
# 타시도 확진자 접촉자      1
# #29 접촉           1
# #6727 첩촉         1
# 오렌지라이프 관련        1
# #8646 접촉         1
# Name: 접촉력, Length: 147, dtype: int64

# %%
# 퍼센트 구하기!

df["접촉력"].value_counts(normalize = True).head(15) * 100
# Out:
# 해외 접촉 추정       19.949174
# 확인 중           11.435832
# 이태원 클럽 관련       8.831004
# 리치웨이 관련         7.560356
# 구로구 콜센터 관련      3.811944
# 타시도 확진자 접촉      3.113088
# 양천구 운동시설 관련     2.731893
# 요양시설 관련         2.731893
# 구로구 교회 관련       2.604828
# 수도권 개척교회 관련     2.350699
# 콜센터직원 접촉        2.350699
# 강남구 사무실 관련      2.096569
# 왕성교회 관련         1.905972
# 동대문구 관련         1.778907
# 부천시 쿠팡 관련       1.524778
# Name: 접촉력, dtype: float64

# %%
# 상위 15개만 구합니다.
contact_count.head(15)
# Out:
# 해외 접촉 추정       314
# 확인 중           180
# 이태원 클럽 관련      139
# 리치웨이 관련        119
# 구로구 콜센터 관련      60
# 타시도 확진자 접촉      49
# 양천구 운동시설 관련     43
# 요양시설 관련         43
# 구로구 교회 관련       41
# 수도권 개척교회 관련     37
# 콜센터직원 접촉        37
# 강남구 사무실 관련      33
# 왕성교회 관련         30
# 동대문구 관련         28
# 부천시 쿠팡 관련       24
# Name: 접촉력, dtype: int64

# %%
# 접촉력 빈도수가 높은 목록에 대한 index 값을 구해옵니다.

top_contact = contact_count.head(15).index
top_contact
# Out:
# Index(['해외 접촉 추정', '확인 중', '이태원 클럽 관련', '리치웨이 관련', '구로구 콜센터 관련', '타시도 확진자 접촉',
#        '양천구 운동시설 관련', '요양시설 관련', '구로구 교회 관련', '수도권 개척교회 관련', '콜센터직원 접촉',
#        '강남구 사무실 관련', '왕성교회 관련', '동대문구 관련', '부천시 쿠팡 관련'],
#       dtype='object')

# %%
# 위에서 구한 top_contact 에 해당되는 데이터만 isin 으로 가져옵니다.
df_top_contact = df[df["접촉력"].isin(top_contact)]

# %%
df[df["접촉력"].isin(["해외 접촉 추정"])]
# Out:
#         연번     환자    확진일   거주지              여행력       접촉력        조치사항  \
# 1     1573  14173  7.26.   강동구               미국  해외 접촉 추정       보라매병원
# 3     1571  14175  7.26.   관악구              필리핀  해외 접촉 추정       보라매병원
# 4     1570  14171  7.26.   용산구              이라크  해외 접촉 추정       서울의료원
# 9     1565  14149  7.25.   서초구               미국  해외 접촉 추정    남산생활치료센터
# 12    1562  14143  7.25.    기타              이라크  해외 접촉 추정      생활치료센터
# ...    ...    ...    ...   ...              ...       ...         ...
# 1304   270   8342  3.17.   성남시               미국  해외 접촉 추정  타시도 이관(퇴원)
# 1305   269   8359  3.17.   송파구               영국  해외 접촉 추정   서울의료원(퇴원)
# 1308   266   8271  3.16.  영등포구  모로코, 프랑스, 오스트리아  해외 접촉 추정   서울의료원(퇴원)
# 1327   247   8096  3.14.   구로구              필리핀  해외 접촉 추정   보라매병원(퇴원)
# 1531    43   1022  2.25.   송파구                -  해외 접촉 추정    서남병원(퇴원)
#
#            확진일자  월   주     월일  요일 요일명    지역
# 1    2020-07-26  7  30  07-26   6   일   강동구
# 3    2020-07-26  7  30  07-26   6   일   관악구
# 4    2020-07-26  7  30  07-26   6   일   용산구
# 9    2020-07-25  7  30  07-25   5   토   서초구
# 12   2020-07-25  7  30  07-25   5   토   타지역
# ...         ... ..  ..    ...  ..  ..   ...
# 1304 2020-03-17  3  12  03-17   1   화   타지역
# 1305 2020-03-17  3  12  03-17   1   화   송파구
# 1308 2020-03-16  3  12  03-16   0   월  영등포구
# 1327 2020-03-14  3  11  03-14   5   토   구로구
# 1531 2020-02-25  2   9  02-25   1   화   송파구
#
# [314 rows x 14 columns]

# %%
# 접촉력, 월별 빈도수를 groupby 로 구합니다.

contact_group = df_top_contact.groupby(["접촉력", "월"])["연번"].count().unstack()
contact_group
# Out:
# 월               2      3      4      5      6     7
# 접촉력
# 강남구 사무실 관련    NaN    NaN    NaN    NaN    2.0  31.0
# 구로구 교회 관련     NaN   35.0    6.0    NaN    NaN   NaN
# 구로구 콜센터 관련    NaN   60.0    NaN    NaN    NaN   NaN
# 동대문구 관련       NaN   28.0    NaN    NaN    NaN   NaN
# 리치웨이 관련       NaN    NaN    NaN    NaN  119.0   NaN
# 부천시 쿠팡 관련     NaN    NaN    NaN   19.0    5.0   NaN
# 수도권 개척교회 관련   NaN    NaN    NaN    NaN   37.0   NaN
# 양천구 운동시설 관련   NaN    NaN    NaN    NaN   43.0   NaN
# 왕성교회 관련       NaN    NaN    NaN    NaN   25.0   5.0
# 요양시설 관련       NaN    NaN    NaN    NaN   43.0   NaN
# 이태원 클럽 관련     NaN    NaN    NaN  133.0    6.0   NaN
# 콜센터직원 접촉      NaN   36.0    1.0    NaN    NaN   NaN
# 타시도 확진자 접촉    5.0   17.0    4.0    2.0    6.0  15.0
# 해외 접촉 추정      1.0  120.0  112.0   24.0   23.0  34.0
# 확인 중         11.0   29.0    9.0   12.0   75.0  44.0

# %%
contact_group = df_top_contact.groupby(["접촉력", "월"])["연번"].count().unstack()
contact_group = contact_group.fillna(0).astype(int)
contact_group.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row0_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row0_col5 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row1_col1 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row1_col2 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row1_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row2_col1 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row3_col1 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row3_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row4_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row5_col3 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row5_col4 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row5_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row6_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row6_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row6_col4 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row6_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row7_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row7_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row7_col4 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row7_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row8_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row8_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row8_col4 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row8_col5 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row9_col4 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_908e89d2_d3b6_11ea_81b3_f8ac65c64f39row9_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;

# %%
# 많은순서대로 글자 순 정렬 하는 방법

contact_group.sort_values(by = [2,3,4,5,6,7],ascending= False).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row0_col1 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row0_col2 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row0_col3 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row0_col4 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row1_col0 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row1_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row1_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row1_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row1_col4 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row1_col5 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row2_col0 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row2_col3 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row2_col4 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row2_col5 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row3_col1 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row3_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row4_col1 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row4_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row4_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row5_col1 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row5_col2 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row5_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row5_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row6_col1 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row6_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row6_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row6_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row7_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row7_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row7_col4 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row7_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row8_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row8_col3 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row8_col4 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row8_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row9_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_909ce15e_d3b6_11ea_b687_f8ac65c64f39row9_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;

# %%
# 컬럼 지정에 따라 월을 정렬 가능하다 

contact_group.sort_values(by = [7,5,4,2,6,3],ascending= False).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row0_col1 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row0_col2 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row0_col3 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row0_col4 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row1_col0 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row1_col3 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row1_col4 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row1_col5 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row2_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row2_col5 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row3_col0 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row3_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row3_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row3_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row3_col4 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row3_col5 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row4_col4 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row4_col5 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row5_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row5_col4 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row5_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row6_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row6_col3 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row6_col4 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row6_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row7_col1 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row7_col2 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row7_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row7_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row8_col1 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row8_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row8_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row8_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row9_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_90aa3cd2_d3b6_11ea_b128_f8ac65c64f39row9_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;

# %%
# 특정 건수만 보고싶을대 

contact_group.loc[['해외 접촉 추정', '확인 중']]
# Out:
# 월          2    3    4   5   6   7
# 접촉력
# 해외 접촉 추정   1  120  112  24  23  34
# 확인 중      11   29    9  12  75  44

# %% [markdown]
# ### 이태원 클럽 관련
# * 이태원 클럽 전파는 5월에 시작되었으나 6월에도 확진자가 있습니다.
# * 6월에 이태원 클럽관련 확진자를 찾아봅니다.

# %%
contact_group.loc[["이태원 클럽 관련"]]
# Out:
# 월          2  3  4    5  6  7
# 접촉력
# 이태원 클럽 관련  0  0  0  133  6  0

# %%
df[df["접촉력"] == "이태원 클럽 관련"]
# Out:
#       연번     환자    확진일  거주지 여행력        접촉력          조치사항       확진일자  월   주  \
# 594  980  11786  6.06.  성동구   -  이태원 클럽 관련     서울의료원(퇴원) 2020-06-06  6  23
# 609  965  11741  6.06.  은평구   -  이태원 클럽 관련     보라매병원(퇴원) 2020-06-06  6  23
# 618  956  11730  6.06.  성동구   -  이태원 클럽 관련     서울대병원(퇴원) 2020-06-06  6  23
# 625  949  11775  6.05.  은평구   -  이태원 클럽 관련   국립중앙의료원(퇴원) 2020-06-05  6  23
# 640  934  11687  6.05.  성동구   -  이태원 클럽 관련     보라매병원(퇴원) 2020-06-05  6  23
# ..   ...    ...    ...  ...  ..        ...           ...        ... ..  ..
# 932  642  10840  5.08.  용산구   -  이태원 클럽 관련  국군수도통합병원(퇴원) 2020-05-08  5  19
# 933  641  10831  5.08.  용산구   -  이태원 클럽 관련   순천향서울병원(퇴원) 2020-05-08  5  19
# 934  640  10839  5.08.  용산구   -  이태원 클럽 관련   순천향서울병원(퇴원) 2020-05-08  5  19
# 935  639  10832  5.08.  용산구   -  이태원 클럽 관련   순천향서울병원(퇴원) 2020-05-08  5  19
# 936  638  10833  5.08.  종로구   -  이태원 클럽 관련     보라매병원(퇴원) 2020-05-08  5  19
#
#         월일  요일 요일명   지역
# 594  06-06   5   토  성동구
# 609  06-06   5   토  은평구
# 618  06-06   5   토  성동구
# 625  06-05   4   금  은평구
# 640  06-05   4   금  성동구
# ..     ...  ..  ..  ...
# 932  05-08   4   금  용산구
# 933  05-08   4   금  용산구
# 934  05-08   4   금  용산구
# 935  05-08   4   금  용산구
# 936  05-08   4   금  종로구
#
# [139 rows x 14 columns]

# %% [markdown]
# 이태원 클럽 관련 퇴원 이랑 아닌수 걸러내는 작업해보기

# %% [markdown]
# ### 감염경로 불명

# %%
# "접촉력" 이 "확인 중"인 데이터만 구합니다.

df_unknown = df[df["접촉력"] == "확인 중"].copy()
df_unknown.head()
# Out:
#       연번     환자    확진일   거주지 여행력   접촉력   조치사항       확진일자  월   주     월일  요일  \
# 5   1569  14161  7.26.    중구   -  확인 중  보라매병원 2020-07-26  7  30  07-26   6
# 11  1563  14147  7.25.   송파구   -  확인 중  서울의료원 2020-07-25  7  30  07-25   5
# 14  1560  14142  7.25.  동대문구   -  확인 중  서울의료원 2020-07-25  7  30  07-25   5
# 23  1551  14065  7.24.   은평구   -  확인 중   서북병원 2020-07-24  7  30  07-24   4
# 34  1540  13976  7.23.   송파구   -  확인 중   서남병원 2020-07-23  7  30  07-23   3
#
#    요일명    지역
# 5    일    중구
# 11   토   송파구
# 14   토  동대문구
# 23   금   은평구
# 34   목   송파구

# %%
# 감염경로 불명이 어느정도인지 봅니다.

df_unknown.shape
# Out:
# (180, 14)

# %%
# 전체 확진수를 value_counts 로 구하고 데이터프레임 형태로 만듭니다.
# all_weekly_case

all_weekly_case = df["주"].value_counts()
all_weekly_case.head()
# Out:
# 23    134
# 14    128
# 24    125
# 11    124
# 25    106
# Name: 주, dtype: int64

# %%
# 전체 확진수를 value_counts 로 구하고 데이터프레임 형태로 만듭니다.
# unknown_weekly_case

unknown_weekly_case = df_unknown["주"].value_counts()
unknown_weekly_case.head()
# Out:
# 24    25
# 23    18
# 30    16
# 25    16
# 27    13
# Name: 주, dtype: int64

# %%
# all_weekly_case 와 unknown_weekly_case 를 비교해 봅니다.
# 저번에  머지를 사용

all_unknown = pd.DataFrame({"주별 확진": all_weekly_case, 
                            "감염경로 불명 확진": unknown_weekly_case}).fillna(0)

# %%
# 위에서 구한 결과를 시각화 합니다.

all_unknown.plot(figsize = (15,4))

# %%
all_unknown.head
# Out:
#     주별 확진  감염경로 불명 확진    확인중 비율
# 4       1         0.0  0.000000
# 5       7         0.0  0.000000
# 6       4         0.0  0.000000
# 7       2         0.0  0.000000
# 8      17         0.0  0.000000
# 9      62        11.0  0.177419
# 10     37         4.0  0.108108

# %%
# 감염경로 "확인 중"의 주별 비율

all_unknown["확인중 비율"] = all_unknown["감염경로 불명 확진"]/all_unknown["주별 확진"]
all_unknown["확인중 비율"].sort_values(ascending=False)
# Out:
# 24    0.200000
# 27    0.194030
# 28    0.192982
# 29    0.187500
# 9     0.177419
# 30    0.164948
# 25    0.150943
# 26    0.141026
# 23    0.134328
# 12    0.131579
# 22    0.114943
# 10    0.108108
# 15    0.106383
# 11    0.088710
# 16    0.066667
# 14    0.031250
# 13    0.028571
# 21    0.025641
# 20    0.020833
# 7     0.000000
# 6     0.000000
# 5     0.000000
# 17    0.000000
# 8     0.000000
# 18    0.000000
# 19    0.000000
# 4     0.000000
# Name: 확인중 비율, dtype: float64

# %% [markdown]
# ## 가장 많은 전파가 일어난 번호
# * [정규 표현식 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EC%A0%95%EA%B7%9C_%ED%91%9C%ED%98%84%EC%8B%9D)
#
#
# * 파이썬 공식문서 정규표현식 참고하기 :
#     * https://docs.python.org/3.8/library/re.html#re.sub
#
#
# * 문자열 바꾸기 : re.sub("규칙", "패턴", "데이터")
#     * https://docs.python.org/3.8/library/re.html#text-munging
#
#
# * 정규표현식 문자열 패턴
#     * https://docs.python.org/3.8/howto/regex.html#matching-characters
#
#
#
# * [    ] : 일치시킬 문자 세트의 패턴
# * [가나다] : 가 or 나 or 다 중에 하나를 포함하고 있는지
# * [가-힣] : 한글 가부터 힣까의 문자 중 하나를 포함하고 있는지
# * [0-9] : 0~9까지의 숫자 중 하나를 포함하고 있는지
# * [^0-9] : 숫자를 포함하고 있지 않음
# * [^가-힣] : 한글이 포함되어 있지 않음
# * [가-힣+] : 한글이 하나 이상 포함되는지

# %%
import re
# 정규표현식 라이브러리를 불러옵니다.
# 숫자외의 데이터는 제거하는 정규표현식
# #7265 접촉(추정)

re.sub("[0-9]", "", "7265 접촉(추정)")
# Out:
# ' 접촉(추정)'

# %%
re.sub("[^0-9]", "", "7265 접촉(추정)")
# Out:
# '7265'

# %%
# 함수를 통해 숫자외의 문자를 제거하는 get_number 함수를 만듭니다.

def get_number(x):
    return x

get_number("7265 접촉(추정)")
# Out:
# '7265 접촉(추정)'

# %%
def get_number(x):
    return re.sub("[^0-9]", "", x)

get_number("7265 접촉(추정)")
# Out:
# '7265'

# %%
# 함수를 map을 통해 접촉번호를 구합니다.

df["접촉번호"] = df["접촉력"].map(get_number)
contact_number = df["접촉번호"].value_counts()

# %%
# 접촉번호가 없는 0번 행은 drop 으로 삭제합니다.
# 한번 drop 한 셀을 다시 drop 하면 이미 삭제를 했는데 다시 삭제하려 하기 때문에 KeyError 가 납니다. 
# 다시 실행했을 때 KeyError 가 발생하는 것이 정상입니다.

df_contact_number = contact_number.reset_index()
df_contact_number.columns = ["접촉번호", "접촉수"]
df_contact_number = df_contact_number.drop(0)
df_contact_number.head()
# Out:
#    접촉번호  접촉수
# 1  9734    4
# 2     6    4
# 3  8271    3
# 4  8791    3
# 5  8486    3

# %%
# 상위 10개의 접촉번호를 구해서 top_contact_no 변수에 할당하고 재사용합니다.

df_contact_number["접촉수"].describe()
# Out:
# count    61.000000
# mean      1.393443
# std       0.758918
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max       4.000000
# Name: 접촉수, dtype: float64

# %%
# contact의 환자번호와 df의 접촉번호를 merge 합니다.

df
# Out:
#         연번     환자    확진일  거주지     여행력         접촉력         조치사항       확진일자  월  \
# 0     1574  14172  7.26.  송파구       -  송파구 확진자 접촉        서울의료원 2020-07-26  7
# 1     1573  14173  7.26.  강동구      미국    해외 접촉 추정        보라매병원 2020-07-26  7
# 2     1572  14165  7.26.  종로구       -  송파구 확진자 접촉        서울의료원 2020-07-26  7
# 3     1571  14175  7.26.  관악구     필리핀    해외 접촉 추정        보라매병원 2020-07-26  7
# 4     1570  14171  7.26.  용산구     이라크    해외 접촉 추정        서울의료원 2020-07-26  7
# ...    ...    ...    ...  ...     ...         ...          ...        ... ..
# 1569     5      9  1.31.  성북구       -       #5 접촉    서울의료원(퇴원) 2020-01-31  1
# 1570     4      7  1.30.  마포구  중국 우한시       해외 접촉    서울의료원(퇴원) 2020-01-30  1
# 1571     3      6  1.30.  종로구       -       #3 접촉  서울대학교병원(퇴원) 2020-01-30  1
# 1572     2      5  1.30.  중랑구  중국 우한시       해외 접촉    서울의료원(퇴원) 2020-01-30  1
# 1573     1      2  1.24.  강서구  중국 우한시       해외 접촉  국립중앙의료원(퇴원) 2020-01-24  1
#
#        주     월일  요일 요일명   지역 접촉번호
# 0     30  07-26   6   일  송파구
# 1     30  07-26   6   일  강동구
# 2     30  07-26   6   일  종로구
# 3     30  07-26   6   일  관악구
# 4     30  07-26   6   일  용산구
# ...   ..    ...  ..  ..  ...  ...
# 1569   5  01-31   4   금  성북구    5
# 1570   5  01-30   3   목  마포구
# 1571   5  01-30   3   목  종로구    3
# 1572   5  01-30   3   목  중랑구
# 1573   4  01-24   4   금  강서구
#
# [1574 rows x 15 columns]

# %% [markdown]
# ## 조치사항

# %%
# 조치사항에 대한 빈도수를 세어봅니다.
# value_counts 는 Series 에만 사용할 수 있습니다.
# 단일 변수의 빈도수를 세는데 사용합니다.

df["조치사항"].value_counts()
# Out:
# 서울의료원(퇴원)      413
# 보라매병원(퇴원)      264
# 서남병원(퇴원)       252
# 생활치료센터(퇴원)      95
# 서북병원(퇴원)        69
#               ...
# 서울대학교병원(사망)      1
# 순천향서울병원(사망)      1
# 한양대학교병원          1
# 강북삼성병원(사망)       1
# 서납병원(퇴원)         1
# Name: 조치사항, Length: 84, dtype: int64

# %% [markdown]
# ## 퇴원, 사망여부

# %%
# 데이터 수집 시점에서 퇴원하지 못한 환자수

df["조치사항"].re.split("퇴원", "사망")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-143-9e28c25fbab3> in <module>
#       1 # 데이터 수집 시점에서 퇴원하지 못한 환자수
#       2
# ----> 3 df["조치사항"].re.split("퇴원", "사망")
#
# C:\Anaconda3_64\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 're'

# %%
# 퇴원여부 빈도수에 대한 비율을 구합니다.

# %%
# 사망여부에 따른 빈도수를 구합니다.

# %%
# 사망 여부에 따른 빈도수의 비율을 구합니다.

# %% [markdown]
# * 데이터 수집 시점 기준 현재까지 입원해 있는 확진자 중 가장 오래 입원해 있는 확진자

# %%
# 데이터 수집 시점 기준 현재까지 입원해 있는 확진자 중 가장 오래 입원해 있는 확진자

# %% [markdown]
# ## 병원

# %%
# describe 로 요약을 합니다.
# count : 빈도수
# unique : 병원수
# top : 가장 많은 빈도로 등장하는 텍스트
# freq : 가장 많은 빈도의 횟수

# %%
# 병원의 빈도수를 구합니다.

# %%
# 병원별 빈도수를 막대그래프로 표현합니다.

# %%
# 입원환자가 많은 병원을 구합니다.

# %% [markdown]
# ### iloc 로 일부 데이터만 보기

# %%
# 전체 데이터를 보기에 너무 많을 수 있기 때문에 iloc 를 사용해서 일부 데이터만 봅니다.

# %% [markdown]
# ### loc로 일부 데이터만 보기
# * iloc 와 loc의 차이점을 비교해 보세요.

# %% [markdown]
# ### pandas style 적용하기

# %%
# 전체 병원이 너무 많기 때문에 환자가 많은 병원만 따로 봅니다.

# %% [markdown]
# ## 여행력

# %%
# "해외" 라는 컬럼을 만들어 데이터를 전처리 합니다.
# "여행력"에 "-" 문자가 들어가 있으면 결측치로 처리합니다.
# df["해외"]

# %%
# describe 로 요약을 합니다.
# count : 빈도수
# unique : 병원수
# top : 가장 많은 빈도로 등장하는 텍스트
# freq : 가장 많은 빈도의 횟수

# %% [markdown]
# ### 여행력이 있는 데이터만 가져와서 서브셋 만들기

# %%
# "해외" 컬럼의 값이 결측치가 아닌 데이터만 가져와서 
# df_oversea 라는 새로운 데이터프레임에 담습니다.

# %%
# 중복되는 지역명이 있는지 확인합니다.

# %% [markdown]
# ### 텍스트 데이터 다루기
# [Working with text data — pandas documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#testing-for-strings-that-match-or-contain-a-pattern)

# %%
# 유럽 지역을 방문했다면 유럽이라고 바꿔주기 위해 국가명을 str.contains 로 검색하기 위한 형태로 만듭니다.
europe = "체코, 헝가리, 오스트리아, 이탈리아, 프랑스, 모로코, 독일, 스페인, 영국, 폴란드, 터키, 아일랜드"

# %%
# 남미 지역에 해당되는 국가명을 str.contains 로 검색하기 위한 형태로 만듭니다.
south_america = "브라질, 아르헨티아, 칠레, 볼리비아, 멕시코, 페루"

# %%
# 중복되는 국가나 지역을 특정 텍스트로 변경해서 그룹화 해서 빈도수를 세어볼 예정입니다.
# .str.contains 와 .loc 를 사용해서 전처리 합니다.

# %%
# describe 로 요약을 합니다.
# count : 빈도수
# unique : 병원수
# top : 가장 많은 빈도로 등장하는 텍스트
# freq : 가장 많은 빈도의 횟수

# %%
# 확진일자, 해외 별 카운트 수를 구합니다.

# %%
# 위에서 구한 값을 바탕으로 지역별 누적 확진수를 구합니다.

# %%
# 위에서 구한 값을 reset_index() 를 통해 데이터프레임으로 변경하고 "연번" 컬럼을 "확진자수"로 변경합니다.

# %%
# "해외" 컬럼의 빈도수를 구합니다.

# %%
# 위에서 구한 빈도수를 시각화 합니다.

# %%
# "해외유입 구별 확진자" 시각화 하기

# %% [markdown]
# ### 전체확진수와 해외유입 확진수 비교

# %%
# all_count_gu 변수에 전체 지역의 확진자수 구하기

# %%
# 데이터프레임으로 변환하고 컬럼명 변경하기

# %%
# 해외유입확진수 구하기

# %% [markdown]
# ### merge 를 통해 전체 확진수와 해외유입확진수 비교하기
# * 이미지 출처 및 Pandas 공식문서 보기 : [How to combine data from multiple tables? — pandas documentation](https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/08_combine_dataframes.html#join-tables-using-a-common-identifier)
#
# <img src="https://pandas.pydata.org/pandas-docs/stable/_images/08_merge_left.svg">

# %%
# merge 로 합쳐서 전체확진수와 해외유입확진수 비교해 보기

# %%
# 시각화 하기

# %%
# df_all_oversea_case["해외유입비율"] 구하기

# %% [markdown]
# ### 해외유입 확진자 중 퇴원 여부

# %%
# oversea_finish_count 해외유입 확진자 중 퇴원 여부 구하기

# %% [markdown]
# ### 월별 해외 확진자 수

# %% [markdown]
# ### 구와 월별 해외 확진자 수
# * groupby, crosstab, pivot_table 로 같은 결과의 테이블이 나오도록 구합니다.
# #### groupby 로 빈도수 구하기

# %% [markdown]
# #### crosstab 으로 빈도수 구하기

# %% [markdown]
# #### pivot_table 로 빈도수 구하기

# %% [markdown]
# ### 해외유입이 많은 지역

# %%
# 해외유입이 많은 상위 10개 지역을 구합니다.
# top_oversea_gu

# %%
# 시각화 하기

# %% [markdown]
# ### 구별 해외유입 국가 분석하기
# #### groupby 로 구하기

# %% [markdown]
# #### pivot table 로 구하기
# * groupby 로 구한 결과와 같은 결과가 나오게 구합니다.

# %% [markdown]
# #### 일부 구만 따로 보기
# * 전체는 너무 많기 때문에 특정 구만 따로 봅니다.

# %%
# 강남 3구의 입국자는 해외 어느 지역에서 입국했나?

# %%
# top_oversea_gu 에 따른 확진수 보기

# %% [markdown]
# ### 최근 데이터를 불러와 실습해 보기
# * 이 실습을 진행하고 계신 여러분들은 이 시점보다 미래에 있겠죠?
# * 같은 내용의 실습을 최근 데이터로 해보세요!
